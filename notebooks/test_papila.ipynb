# %% [markdown]
# # Test PAPILA Dataloader
#
# This notebook verifies the dataset loader for the
# **PAPILA** dataset.

# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from dataloader.papila import PAPILAModule

from utils.transforms import eval_transform
print("Python path:", os.getcwd())
root = os.environ.get("PAPILAModule", PAPILAModule)
print("Using root:", root)
assert os.path.exists(root), f"Dataset root not found: {root}"
transform = eval_transform(224)
dm = PAPILAModule(root=root, transform=transform, batch_size=8)
dm.setup(stage="full")
print("Dataset ready")
try:
    loader = dm.val_dataloader()
except Exception as exc:
    raise
print("len(val_ds)=", len(dm.val_ds))
batch = next(iter(loader))
imgs, labels, paths = batch
print("batch images shape:", imgs.shape)
print("batch labels shape:", labels.shape)
print("sample paths:", paths[:3])
# Out:
# Python path: /home/andremitri/code/LEMUR/notebooks
# Using root: <class 'dataloader.papila.PAPILAModule'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      11 root = os.environ.get("PAPILAModule", PAPILAModule)
#      12 print("Using root:", root)
# ---> 13 assert os.path.exists(root), f"Dataset root not found: {root}"
#      14 transform = eval_transform(224)
#      15 dm = PAPILAModule(root=root, transform=transform, batch_size=8)
#
# File ~/miniconda3/envs/mae/lib/python3.10/genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not type
